# %%
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dataset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import torch.nn.utils.spectral_norm as spectral_norm
import os

# %% [markdown]
# Define the variables that will be used in the design of the Neural Networks

# %%
workers = 2
image_size  = 64
batch_size = 64
no_of_channels = 3 # SInce it is an RGB image so there are 3 channels that is being predefined 
nz = 100 # Size of the noise
ngf = 64 # Size of the Feature map in Generator
ndf = 64 # Size of feature map in Discriminator
#epochs = 10
#lr = 0.0002
#beta1 = 0.5
ngpu = 1
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %%
transform=transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                              ]) # Normalizing the image to contain data b/w [0,1]

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
data = dataset.ImageFolder(root = '/content/gdrive/My Drive/CelebA/', transform= transform)

# %%
data_subset = torch.utils.data.Subset(data, np.random.choice(len(data), len(data)-(len(data) % batch_size), replace = False))

# %%
len(data_subset)
# Out:
# 69312

# %% [markdown]
# Visualizing the Data

# %%
dataloader = torch.utils.data.DataLoader(data_subset, batch_size= batch_size, shuffle = True, num_workers = workers) # Returns an iterable

# %%
data_iter  = iter(dataloader) # Created the iterator

# %%
batch_data = next(data_iter) #Calling the first sample or batch of Images

# %%
#len(dataloader.batch_sampler)

# %%
#batch_datap[0].size()# Torchvision automatically makes the image data channel first

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu >0) else "cpu")

# %%
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(batch_data[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ## Defining the Networks
# Defining the Self Attention layer , Generator and the Discriminator Networks, Self Attention has been designed as per the concept introduced in Vaswani et.al's paper "Attention is All You Need" and Zhnang et.al's paper "Self Attention Generative Adversarial Networks"

# %%
class SelfAttention(nn.Module):
  def __init__(self, ngpu, in_dim):
    super(SelfAttention, self).__init__()
    self.ngpu = ngpu # Here I am specifying the gpu for storage purposes and better matrix multiplication
    self.fx = nn.Conv2d(in_channels=in_dim, out_channels=in_dim//2, kernel_size=1)
    self.gx = nn.Conv2d(in_channels= in_dim, out_channels= in_dim//2, kernel_size=1)
    self.hx = nn.Conv2d(in_channels=in_dim, out_channels=in_dim, kernel_size=1)
    self.gamma = nn.Parameter(torch.zeros(1)) # Creates a trainable parameter
    self.softmax = nn.Softmax(dim = -1)
  
  def forward(self, x):
    m_batch_size, C, width, height = x.size() # Returns a list , the first one contains the Batch_size, C  = No.of channels, Width and height
    fx = self.fx(x).view(m_batch_size, -1, width*height).permute(0,2,1) # transpose the output of the previous layer matrix acording to definition, basically a vector is created by using view (x)
    gx = self.gx(x).view(m_batch_size, -1, width*height)
    hx = self.hx(x).view(m_batch_size, -1, width * height)
    product = torch.bmm(fx, gx) # Basically a dot product is calculated between the resultant tensors
    attention_map = self.softmax(product) # B *N * N
    out = torch.bmm(hx, attention_map.permute(0,2,1)) # Returns tensor of dimensions B*N*C
    out = out.view(batch_size,C, width, height) # Returns Tensor of dimension B * C * W * H
    y = self.gamma * out +x
    y = y.view(m_batch_size, -1, width , height)
    return y

# %%
class Generator(nn.Module):
  def __init__(self, ngf, nz, no_of_channels):
    super(Generator, self).__init__()
    self.generator = nn.Sequential(
                        spectral_norm(nn.ConvTranspose2d(in_channels= nz,out_channels= ngf * 8, kernel_size=4, stride= 1, padding = 0)),
                        nn.BatchNorm2d(ngf * 8),
                        nn.ReLU(),
                        spectral_norm(nn.ConvTranspose2d(in_channels=ngf * 8, out_channels= ngf * 4, kernel_size=4, stride = 2, padding = 1)),
                        nn.BatchNorm2d(ngf*4),
                        nn.ReLU(),
                        spectral_norm(nn.ConvTranspose2d(in_channels=ngf * 4, out_channels= ngf * 2, kernel_size=4, stride=2,padding=1)),
                        nn.BatchNorm2d(ngf * 2),
                        nn.ReLU(),
                        SelfAttention(ngpu, in_dim = ngf * 2),
                        spectral_norm(nn.ConvTranspose2d(in_channels=ngf * 2, out_channels= ngf , kernel_size=4, stride=2,padding=1)),
                        nn.BatchNorm2d(ngf),
                        nn.ReLU(),
                        SelfAttention(ngpu, in_dim = ngf),
                        nn.ConvTranspose2d(in_channels=ngf , out_channels= no_of_channels, kernel_size=4, stride=2,padding=1),
                        #nn.BatchNorm2d(no_of_channels),
                        nn.Tanh()                    
                        )
  def forward(self,input):
      return self.generator(input)

# %%
class Discriminator(nn.Module):
  def __init__(self, ndf, ngpu, no_of_channels):
    super(Discriminator, self).__init__()
    self.ngpu = ngpu
    self.discriminator = nn.Sequential(
                            spectral_norm(nn.Conv2d(in_channels=no_of_channels, out_channels= ndf, kernel_size=4, stride = 2, padding = 1)),
                            nn.BatchNorm2d(ndf),
                            nn.LeakyReLU(0.1),
                            spectral_norm(nn.Conv2d(in_channels=ndf, out_channels= ndf * 2, kernel_size=4,stride = 2, padding = 1 )),
                            nn.BatchNorm2d(ndf * 2),
                            nn.LeakyReLU(0.1),
                            spectral_norm(nn.Conv2d(in_channels=ndf * 2, out_channels= ndf * 4, kernel_size= 4, stride=  2, padding = 1)),
                            nn.BatchNorm2d(ndf * 4),
                            nn.LeakyReLU(0.1),
                            SelfAttention(ngpu, ndf * 4),
                            spectral_norm(nn.Conv2d(in_channels = ndf * 4, out_channels = ndf * 8, kernel_size = 4, stride = 2, padding = 1)),
                            nn.BatchNorm2d(ndf * 8),
                            nn.LeakyReLU(0.1),
                            SelfAttention(ngpu, in_dim = ndf * 8),
                            nn.Conv2d(in_channels= ndf * 8, out_channels = 1, kernel_size= 4, stride= 2, padding= 0),
                            #nn.BatchNorm2d(1),
                            #nn.Tanh()
                          )
  def forward(self, input):
      out = self.discriminator(input)
      return out.squeeze()

# %%
netGenerator = Generator(ngf, nz, no_of_channels).to(device)

# %%
netDiscriminator = Discriminator(ndf, ngpu, no_of_channels).to(device)

# %%
print(netGenerator)
# Out:
# Generator(
#   (generator): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): SelfAttention(
#       (fx): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       (gx): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       (hx): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (softmax): Softmax(dim=-1)
#     )
#     (10): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): SelfAttention(
#       (fx): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (gx): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (hx): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (softmax): Softmax(dim=-1)
#     )
#     (14): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (15): Tanh()
#   )
# )

# %%
print(netDiscriminator)
# Out:
# Discriminator(
#   (discriminator): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.1)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.1)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.1)
#     (9): SelfAttention(
#       (fx): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (gx): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (hx): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       (softmax): Softmax(dim=-1)
#     )
#     (10): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.1)
#     (13): SelfAttention(
#       (fx): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (gx): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (hx): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#       (softmax): Softmax(dim=-1)
#     )
#     (14): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %% [markdown]
# ## Defining the training Loop

# %%
epochs = 1000
beta1 = 0
learning_rate_D = 0.0004
learning_rate_G = 0.0001

# %%
real_label, fake_label = 1, 0

# %%
def denorm(t):
  t = t.mul(0.5).add(0.5)
  t = t.clamp(0,1)
  return t

# %%
def train(netDiscriminator, netGenerator, epoch, epochs, optimizerD, optimizerG, loss_Discriminator, loss_Generator):
  #iters = 0
  PATH_TO_FAKE = '/content/gdrive/My Drive/Fake Images/'
  for epoch in range(epoch, epochs):
    for i, data in enumerate(dataloader,0):
      #Train Discriminator
      batch_data = data[0].to(device)
      b_size = batch_data.size(0)
      #label = torch.full(real_label, b_size, device = device)
      #print(batch_data.size())
      output_real = netDiscriminator(batch_data).view(-1) # Reshapes to a 128 sized tensor
      err_Discriminator_real = nn.ReLU()(1.0 - output_real).mean()
      noise = torch.randn(b_size, nz, 1, 1, device = device)
      fake_images = netGenerator(noise)
      output_fake = netDiscriminator(fake_images)
      errDiscrimator_fake = nn.ReLU()(1.0 + output_fake).mean()
      total_loss = err_Discriminator_real+errDiscrimator_fake
      netDiscriminator.zero_grad()
      netGenerator.zero_grad()
      total_loss.backward()
      optimizerD.step()
      #Train Generator
      #if epoch % 5 == 0:
      noise = torch.randn(b_size, nz, 1, 1, device = device)
      fake_images = netGenerator(noise)
      fake_outputs = netDiscriminator(fake_images)
      loss_Generator_fake = -fake_outputs.mean()
      netDiscriminator.zero_grad()
      netGenerator.zero_grad()
      loss_Generator_fake.backward()
      optimizerG.step()
      if(i%50 == 0):
        print('epoch', epoch,'Discrimator Loss', total_loss.item(), 'Generator Loss', loss_Generator_fake.item())
      loss_Discriminator.append(total_loss.item())
      loss_Generator.append(loss_Generator_fake.item())
      #Saving Model after every 100th epoch
      if (epoch % 100) == 0:
        checkpoint_discriminator = {
            'epoch' : epoch,
            'discriminator_model_state_dict':netDiscriminator.state_dict(),
            'optimizer_discriminator_state_dict':optimizerD.state_dict(),
            'loss':loss_Discriminator
            }
        torch.save(checkpoint_discriminator,Discriminator_path)
        checkpoint_generator = {
            'epoch' : epoch ,
            'generator_model_state_dict':netGenerator.state_dict(),
            'optimizer_generator_state_dict':optimizerG.state_dict(),
            'loss':loss_Generator
            }
        torch.save(checkpoint_generator, Generator_path)
      if (epoch % 100 == 0) or ((epoch == epochs - 1) and (i == len(dataloader)-1)):
        fake = netGenerator(fixed_noise)
        path_to_save = os.path.join(PATH_TO_FAKE, 'Generator3_Epoch{}'.format(epoch))
        if os.path.exists(path_to_save):
          #print('inside if')
          for i in range(fake.size()[0]):
            vutils.save_image(denorm(fake[i, :, :, :]),os.path.join(path_to_save,'{}_fake.png'.format(i)))
        else:
         #print('inside else')
          os.mkdir(path_to_save)
          for i in range(fake.size()[0]):
            vutils.save_image(denorm(fake[i, :, :, :]),os.path.join(path_to_save,'{}_fake.png'.format(i)))
        #print(fake.size())
        #Saving for visualization purposes
        vutils.save_image(denorm(fake), os.path.join(PATH_TO_FAKE,'{}_fake_Generator3.png'.format(epoch)))
        #img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

      #iters += 1

# %%
#loss = nn.BCELoss()
fixed_noise = torch.randn(batch_size, nz, 1,1, device= device)
optimizerD = optim.Adam(netDiscriminator.parameters(), lr = learning_rate_D, betas =  (beta1, 0.9))
optimizerG = optim.Adam(netGenerator.parameters(), lr = learning_rate_G, betas = (beta1, 0.9))
loss_Discriminator = []
loss_Generator = []
iters = 0
img_list = []
Discriminator_path = '/content/gdrive/My Drive/SAGAN Models/Discriminator_with_spectral_norm1.pt'
Generator_path = '/content/gdrive/My Drive/SAGAN Models/Generator_with_spectral_norm_1.pt'

# %%
train(netDiscriminator, netGenerator, 0, epochs, optimizerD, optimizerG,loss_Discriminator, loss_Generator)
# Out:
# epoch 0 Discrimator Loss 1.8771393299102783 Generator Loss 3.423780918121338
# epoch 0 Discrimator Loss 0.019582431763410568 Generator Loss 4.536688327789307
# epoch 0 Discrimator Loss 2.343744993209839 Generator Loss 10.613974571228027
# epoch 0 Discrimator Loss 0.0 Generator Loss 6.835827827453613
# epoch 0 Discrimator Loss 1.5586333274841309 Generator Loss 14.726454734802246
# epoch 0 Discrimator Loss 0.0 Generator Loss 5.142535209655762
# epoch 0 Discrimator Loss 0.02202538028359413 Generator Loss 3.5816895961761475
# epoch 0 Discrimator Loss 0.0 Generator Loss 3.280888557434082
# epoch 0 Discrimator Loss 0.18298766016960144 Generator Loss 4.69599723815918
# epoch 0 Discrimator Loss 0.01138317584991455 Generator Loss 2.9601168632507324
# epoch 0 Discrimator Loss 2.0415568351745605 Generator Loss 3.1783673763275146
# epoch 0 Discrimator Loss 0.0003506047651171684 Generator Loss 3.798353910446167
# epoch 0 Discrimator Loss 0.0 Generator Loss 4.10533332824707
# epoch 0 Discrimator Loss 4.810478210449219 Generator Loss 1.9106075763702393
# epoch 0 Discrimator Loss 0.044854406267404556 Generator Loss 1.8839855194091797
# epoch 0 Discrimator Loss 0.004916919395327568 Generator Loss 3.2244229316711426
# epoch 0 Discrimator Loss 0.059751369059085846 Generator Loss 2.381206512451172
# epoch 0 Discrimator Loss 0.1355908215045929 Generator Loss 7.564643383026123
# epoch 0 Discrimator Loss 1.3015973567962646 Generator Loss 1.1649831533432007
# epoch 0 Discrimator Loss 0.09187410026788712 Generator Loss 6.291903972625732
# epoch 0 Discrimator Loss 0.03166041523218155 Generator Loss 3.314243793487549
# epoch 0 Discrimator Loss 1.5122449398040771 Generator Loss 0.6290954351425171
# epoch 1 Discrimator Loss 0.12557493150234222 Generator Loss 4.302459716796875
# epoch 2 Discrimator Loss 0.03721209615468979 Generator Loss 5.6040215492248535
# epoch 2 Discrimator Loss 0.0 Generator Loss 5.403726577758789
# epoch 2 Discrimator Loss 0.027032122015953064 Generator Loss 4.517911434173584
# epoch 2 Discrimator Loss 0.18340778350830078 Generator Loss 5.1510419845581055
# epoch 2 Discrimator Loss 0.2954096794128418 Generator Loss 11.752340316772461
# epoch 3 Discrimator Loss 0.0 Generator Loss 6.539249420166016
# epoch 3 Discrimator Loss 0.15793168544769287 Generator Loss 8.502734184265137
# epoch 3 Discrimator Loss 0.004322823137044907 Generator Loss 3.005197048187256
# epoch 3 Discrimator Loss 0.02464347332715988 Generator Loss 4.2649827003479
# epoch 3 Discrimator Loss 0.009634356014430523 Generator Loss 6.175128936767578
# epoch 3 Discrimator Loss 0.014372214674949646 Generator Loss 3.2282087802886963
# epoch 3 Discrimator Loss 0.02296788990497589 Generator Loss 3.88767409324646
# epoch 3 Discrimator Loss 0.0 Generator Loss 5.471076011657715
# epoch 3 Discrimator Loss 0.08925013989210129 Generator Loss 3.7536613941192627
# epoch 3 Discrimator Loss 0.0 Generator Loss 4.322018146514893
# epoch 3 Discrimator Loss 0.04506634548306465 Generator Loss 5.067243576049805
# epoch 3 Discrimator Loss 0.0153152821585536 Generator Loss 5.160737037658691
# epoch 3 Discrimator Loss 0.007320195436477661 Generator Loss 3.158470630645752
# epoch 3 Discrimator Loss 0.0 Generator Loss 4.701465606689453
# epoch 3 Discrimator Loss 0.5360793471336365 Generator Loss 3.500185966491699
# epoch 3 Discrimator Loss 0.03126101940870285 Generator Loss 5.455389499664307
# epoch 3 Discrimator Loss 0.0 Generator Loss 4.478557586669922
# epoch 3 Discrimator Loss 0.026723235845565796 Generator Loss 4.546104907989502
# epoch 3 Discrimator Loss 0.0 Generator Loss 4.035663604736328
# epoch 3 Discrimator Loss 0.0 Generator Loss 6.59226131439209
# epoch 3 Discrimator Loss 0.0 Generator Loss 5.888228893280029
# epoch 3 Discrimator Loss 0.017711162567138672 Generator Loss 8.10154914855957
# epoch 4 Discrimator Loss 0.22156807780265808 Generator Loss 11.862079620361328
# epoch 4 Discrimator Loss 0.023603934794664383 Generator Loss 4.371933937072754
# epoch 4 Discrimator Loss 0.0 Generator Loss 3.8948380947113037
# epoch 4 Discrimator Loss 0.00016535911709070206 Generator Loss 4.331669807434082
# epoch 4 Discrimator Loss 0.03795500472187996 Generator Loss 3.4677414894104004
# epoch 4 Discrimator Loss 0.0 Generator Loss 4.462858200073242
# epoch 4 Discrimator Loss 0.009799784049391747 Generator Loss 4.100611209869385
# epoch 4 Discrimator Loss 0.018690505996346474 Generator Loss 5.156980514526367
# epoch 4 Discrimator Loss 0.0 Generator Loss 4.806610107421875
# epoch 4 Discrimator Loss 0.0 Generator Loss 6.663865089416504
# epoch 4 Discrimator Loss 0.032610032707452774 Generator Loss 4.169326305389404
# epoch 4 Discrimator Loss 0.0 Generator Loss 5.6663818359375
# epoch 9 Discrimator Loss 0.6558326482772827 Generator Loss 7.188066482543945
# epoch 10 Discrimator Loss 0.0 Generator Loss 5.4335432052612305
# epoch 10 Discrimator Loss 0.0 Generator Loss 4.613297939300537
# epoch 10 Discrimator Loss 0.09289321303367615 Generator Loss 9.579937934875488
# epoch 10 Discrimator Loss 0.011384692043066025 Generator Loss 6.450730323791504
# epoch 10 Discrimator Loss 0.0058578066527843475 Generator Loss 3.8792099952697754
# epoch 10 Discrimator Loss 0.05819166079163551 Generator Loss 8.146800994873047
# epoch 10 Discrimator Loss 0.0 Generator Loss 5.334932804107666
# epoch 10 Discrimator Loss 0.028443049639463425 Generator Loss 5.339621067047119
# epoch 10 Discrimator Loss 0.0 Generator Loss 8.192920684814453
# epoch 10 Discrimator Loss 0.023669127374887466 Generator Loss 6.649258613586426
# epoch 10 Discrimator Loss 0.0058459993451833725 Generator Loss 4.497661590576172
# epoch 10 Discrimator Loss 0.12277363985776901 Generator Loss 9.134767532348633
# epoch 10 Discrimator Loss 0.0 Generator Loss 6.305100917816162
# epoch 10 Discrimator Loss 0.00884681474417448 Generator Loss 5.966527938842773
# epoch 10 Discrimator Loss 0.06724559515714645 Generator Loss 8.6897611618042
# epoch 10 Discrimator Loss 0.010672342032194138 Generator Loss 4.269281387329102
# epoch 10 Discrimator Loss 0.0 Generator Loss 5.452544212341309
# epoch 10 Discrimator Loss 0.035462938249111176 Generator Loss 8.642183303833008
# epoch 10 Discrimator Loss 0.007059463299810886 Generator Loss 6.954962253570557
# epoch 10 Discrimator Loss 0.00356502179056406 Generator Loss 4.323503017425537
# epoch 10 Discrimator Loss 0.0 Generator Loss 4.542853355407715
# epoch 10 Discrimator Loss 0.04221512749791145 Generator Loss 5.7683305740356445
# epoch 11 Discrimator Loss 0.011441545560956001 Generator Loss 4.7501115798950195
# epoch 11 Discrimator Loss 0.0 Generator Loss 5.043869495391846
# epoch 11 Discrimator Loss 0.007733945734798908 Generator Loss 7.187849044799805
# epoch 11 Discrimator Loss 0.001247446984052658 Generator Loss 6.894482135772705
# epoch 11 Discrimator Loss 0.019034044817090034 Generator Loss 5.148014068603516
# epoch 11 Discrimator Loss 0.000588858500123024 Generator Loss 6.0021653175354
# epoch 11 Discrimator Loss 0.0 Generator Loss 5.322998046875
# epoch 11 Discrimator Loss 0.05801200121641159 Generator Loss 2.746840238571167
# epoch 11 Discrimator Loss 0.0737861767411232 Generator Loss 4.905464172363281
# epoch 11 Discrimator Loss 0.0 Generator Loss 5.670085430145264
# epoch 11 Discrimator Loss 0.0015304917469620705 Generator Loss 5.83312463760376
# epoch 11 Discrimator Loss 0.004728306084871292 Generator Loss 5.460716247558594
# epoch 11 Discrimator Loss 0.0 Generator Loss 4.301863193511963
# epoch 11 Discrimator Loss 0.011208398267626762 Generator Loss 7.923218727111816
# epoch 11 Discrimator Loss 0.0 Generator Loss 6.849255561828613
# epoch 11 Discrimator Loss 0.0 Generator Loss 4.674348831176758
# epoch 11 Discrimator Loss 0.0 Generator Loss 4.993348121643066
# epoch 11 Discrimator Loss 0.006313756108283997 Generator Loss 5.852713108062744
# epoch 11 Discrimator Loss 0.002075410448014736 Generator Loss 6.021087646484375
# epoch 11 Discrimator Loss 0.04547114670276642 Generator Loss 8.276055335998535
# epoch 11 Discrimator Loss 0.0 Generator Loss 5.440387725830078
# epoch 11 Discrimator Loss 0.0 Generator Loss 3.764220714569092
# epoch 12 Discrimator Loss 0.0 Generator Loss 3.4983463287353516
# epoch 12 Discrimator Loss 0.012384552508592606 Generator Loss 5.748671531677246
# epoch 12 Discrimator Loss 0.010438479483127594 Generator Loss 3.4652621746063232
# epoch 12 Discrimator Loss 0.035986386239528656 Generator Loss 5.244802951812744
# epoch 12 Discrimator Loss 0.0 Generator Loss 5.480686187744141
# epoch 12 Discrimator Loss 0.004691004753112793 Generator Loss 6.048230171203613
# epoch 12 Discrimator Loss 0.0 Generator Loss 7.675022125244141
# epoch 12 Discrimator Loss 0.02603541687130928 Generator Loss 6.479367256164551
# epoch 12 Discrimator Loss 0.03873544931411743 Generator Loss 8.042236328125
# epoch 12 Discrimator Loss 0.030388545244932175 Generator Loss 6.222192764282227
# epoch 12 Discrimator Loss 0.0 Generator Loss 6.257826805114746
# epoch 12 Discrimator Loss 0.0 Generator Loss 5.3640031814575195
# epoch 12 Discrimator Loss 0.0 Generator Loss 4.993936538696289
# epoch 12 Discrimator Loss 0.03528902679681778 Generator Loss 5.814927577972412
# epoch 12 Discrimator Loss 0.0 Generator Loss 4.83170223236084
# epoch 12 Discrimator Loss 0.002111164852976799 Generator Loss 6.522634506225586
# epoch 12 Discrimator Loss 0.0 Generator Loss 3.874570846557617
# epoch 12 Discrimator Loss 0.0717514380812645 Generator Loss 4.951593399047852
# epoch 12 Discrimator Loss 1.529442548751831 Generator Loss 6.995054244995117
# epoch 12 Discrimator Loss 0.05396907776594162 Generator Loss 7.079499244689941
# epoch 12 Discrimator Loss 0.00239600520581007 Generator Loss 7.0366106033325195
# epoch 12 Discrimator Loss 0.17728015780448914 Generator Loss 11.681192398071289
# epoch 13 Discrimator Loss 0.0 Generator Loss 5.653346061706543
# epoch 13 Discrimator Loss 0.0 Generator Loss 6.724362373352051
# epoch 13 Discrimator Loss 0.08958380669355392 Generator Loss 5.990917682647705
# epoch 13 Discrimator Loss 0.0 Generator Loss 6.730922698974609
# epoch 13 Discrimator Loss 0.0 Generator Loss 4.447108268737793
# epoch 13 Discrimator Loss 0.0 Generator Loss 5.743279457092285
# epoch 13 Discrimator Loss 0.12084580212831497 Generator Loss 2.3473634719848633
# epoch 13 Discrimator Loss 0.05470599979162216 Generator Loss 6.224648475646973
# epoch 13 Discrimator Loss 0.0 Generator Loss 5.079300880432129
# epoch 13 Discrimator Loss 0.0 Generator Loss 5.932568073272705
# epoch 13 Discrimator Loss 0.0 Generator Loss 5.013840675354004
# epoch 13 Discrimator Loss 0.07064797729253769 Generator Loss 6.994307518005371
# epoch 18 Discrimator Loss 0.019296785816550255 Generator Loss 9.308963775634766
# epoch 19 Discrimator Loss 0.0 Generator Loss 10.3011474609375
# epoch 19 Discrimator Loss 0.0 Generator Loss 5.437325954437256
# epoch 19 Discrimator Loss 0.0 Generator Loss 8.152215003967285
# epoch 19 Discrimator Loss 0.006393701769411564 Generator Loss 7.980449676513672
# epoch 19 Discrimator Loss 0.0 Generator Loss 7.654411792755127
# epoch 19 Discrimator Loss 0.0 Generator Loss 9.224183082580566
# epoch 19 Discrimator Loss 0.0 Generator Loss 5.61403751373291
# epoch 19 Discrimator Loss 0.0 Generator Loss 8.87326431274414
# epoch 19 Discrimator Loss 0.0 Generator Loss 6.626513481140137
# epoch 19 Discrimator Loss 0.0 Generator Loss 6.746053218841553
# epoch 19 Discrimator Loss 0.0 Generator Loss 6.75370454788208
# epoch 19 Discrimator Loss 0.0 Generator Loss 7.184825897216797
# epoch 19 Discrimator Loss 0.061571817845106125 Generator Loss 7.088223934173584
# epoch 19 Discrimator Loss 0.022237729281187057 Generator Loss 5.812857627868652
# epoch 19 Discrimator Loss 0.03450210392475128 Generator Loss 5.044761657714844
# epoch 19 Discrimator Loss 0.0 Generator Loss 6.092287063598633
# epoch 19 Discrimator Loss 0.04143569990992546 Generator Loss 9.281721115112305
# epoch 19 Discrimator Loss 0.0 Generator Loss 7.533180236816406
# epoch 19 Discrimator Loss 0.0 Generator Loss 5.295634746551514
# epoch 19 Discrimator Loss 0.19345875084400177 Generator Loss 5.654215335845947
# epoch 19 Discrimator Loss 0.020714741200208664 Generator Loss 4.702150344848633
# epoch 19 Discrimator Loss 0.0 Generator Loss 4.675832748413086
# epoch 20 Discrimator Loss 0.020113419741392136 Generator Loss 5.9266862869262695
# epoch 20 Discrimator Loss 0.0 Generator Loss 6.281912803649902
# epoch 20 Discrimator Loss 0.5613816380500793 Generator Loss 15.702208518981934
# epoch 20 Discrimator Loss 0.024533694609999657 Generator Loss 11.35851764678955
# epoch 20 Discrimator Loss 0.010822732001543045 Generator Loss 8.351808547973633
# epoch 20 Discrimator Loss 0.13792100548744202 Generator Loss 6.476706504821777
# epoch 20 Discrimator Loss 0.005573425441980362 Generator Loss 6.3942790031433105
# epoch 20 Discrimator Loss 0.0 Generator Loss 5.734856605529785
# epoch 20 Discrimator Loss 0.14956003427505493 Generator Loss 4.644176483154297
# epoch 20 Discrimator Loss 0.0 Generator Loss 8.24956226348877
# epoch 20 Discrimator Loss 0.0 Generator Loss 7.207839012145996
# epoch 20 Discrimator Loss 0.011842446401715279 Generator Loss 7.758617401123047
# epoch 20 Discrimator Loss 0.0 Generator Loss 7.0753679275512695
# epoch 20 Discrimator Loss 0.0 Generator Loss 10.882770538330078
# epoch 20 Discrimator Loss 0.0 Generator Loss 6.486024856567383
# epoch 20 Discrimator Loss 0.0 Generator Loss 6.917657375335693
# epoch 20 Discrimator Loss 0.008441993035376072 Generator Loss 7.3216447830200195
# epoch 20 Discrimator Loss 0.01528848335146904 Generator Loss 6.151276588439941
# epoch 20 Discrimator Loss 0.0 Generator Loss 7.175390243530273
# epoch 20 Discrimator Loss 0.02251404896378517 Generator Loss 7.603631019592285
# epoch 20 Discrimator Loss 0.0 Generator Loss 6.921797275543213
# epoch 20 Discrimator Loss 0.0 Generator Loss 7.881424427032471
# epoch 21 Discrimator Loss 0.0 Generator Loss 6.262269020080566
# epoch 21 Discrimator Loss 0.0 Generator Loss 5.400258541107178
# epoch 21 Discrimator Loss 0.006633833050727844 Generator Loss 7.323978424072266
# epoch 21 Discrimator Loss 0.0 Generator Loss 6.068835735321045
# epoch 21 Discrimator Loss 0.0 Generator Loss 5.454341888427734
# epoch 21 Discrimator Loss 0.0 Generator Loss 7.182224273681641
# epoch 21 Discrimator Loss 0.0 Generator Loss 6.258408069610596
# epoch 21 Discrimator Loss 0.0 Generator Loss 5.897360801696777
# epoch 21 Discrimator Loss 0.03180370479822159 Generator Loss 5.568192958831787
# epoch 21 Discrimator Loss 0.12820076942443848 Generator Loss 3.5035958290100098
# epoch 21 Discrimator Loss 0.03133012354373932 Generator Loss 6.539409637451172
# epoch 21 Discrimator Loss 0.0 Generator Loss 4.992639541625977
# epoch 21 Discrimator Loss 0.006641089916229248 Generator Loss 8.958698272705078
# epoch 21 Discrimator Loss 0.543601393699646 Generator Loss 11.251733779907227
# epoch 21 Discrimator Loss 0.0 Generator Loss 7.810809135437012
# epoch 21 Discrimator Loss 0.0 Generator Loss 6.0127410888671875
# epoch 21 Discrimator Loss 0.0 Generator Loss 8.005105972290039
# epoch 21 Discrimator Loss 0.0 Generator Loss 7.742405891418457
# epoch 21 Discrimator Loss 0.0 Generator Loss 8.311689376831055
# epoch 21 Discrimator Loss 0.0 Generator Loss 18.399370193481445
# epoch 21 Discrimator Loss 0.0 Generator Loss 16.277812957763672
# epoch 21 Discrimator Loss 0.0 Generator Loss 11.384454727172852
# epoch 22 Discrimator Loss 0.0 Generator Loss 15.750778198242188
# epoch 22 Discrimator Loss 0.0 Generator Loss 11.757545471191406
# epoch 22 Discrimator Loss 0.0 Generator Loss 8.027982711791992
# epoch 22 Discrimator Loss 0.0 Generator Loss 11.437572479248047
# epoch 22 Discrimator Loss 0.0 Generator Loss 12.191370010375977
# epoch 22 Discrimator Loss 0.0 Generator Loss 7.974549293518066
# epoch 22 Discrimator Loss 0.0 Generator Loss 11.423766136169434
# epoch 22 Discrimator Loss 0.0 Generator Loss 14.48125171661377
# epoch 22 Discrimator Loss 0.0 Generator Loss 9.013304710388184
# epoch 22 Discrimator Loss 0.0 Generator Loss 6.317782402038574
# epoch 22 Discrimator Loss 0.0 Generator Loss 9.742847442626953
# epoch 22 Discrimator Loss 0.0 Generator Loss 9.268438339233398
# epoch 22 Discrimator Loss 0.0 Generator Loss 10.105206489562988
# epoch 22 Discrimator Loss 0.2554919421672821 Generator Loss 24.472387313842773
# epoch 22 Discrimator Loss 0.051445163786411285 Generator Loss 13.736183166503906
# epoch 22 Discrimator Loss 0.025619138032197952 Generator Loss 14.894316673278809
# epoch 22 Discrimator Loss 0.0 Generator Loss 15.343341827392578
# epoch 22 Discrimator Loss 3.237318754196167 Generator Loss 18.116146087646484
# epoch 22 Discrimator Loss 0.0 Generator Loss 7.995407581329346
# epoch 22 Discrimator Loss 0.041100870817899704 Generator Loss 1.9209283590316772
# epoch 22 Discrimator Loss 0.003951868042349815 Generator Loss 8.107778549194336
# epoch 22 Discrimator Loss 0.03473694995045662 Generator Loss 11.602621078491211
# epoch 23 Discrimator Loss 0.0 Generator Loss 7.879210472106934
# epoch 23 Discrimator Loss 0.33552300930023193 Generator Loss 23.70142364501953
# epoch 23 Discrimator Loss 0.7378917932510376 Generator Loss 20.778160095214844
# epoch 23 Discrimator Loss 0.0 Generator Loss 12.257232666015625
# epoch 23 Discrimator Loss 0.17186708748340607 Generator Loss 8.26953411102295
# epoch 23 Discrimator Loss 0.05362353101372719 Generator Loss 7.39655065536499
# epoch 23 Discrimator Loss 0.0 Generator Loss 8.564469337463379
# epoch 23 Discrimator Loss 0.0 Generator Loss 8.521869659423828
# epoch 23 Discrimator Loss 0.0 Generator Loss 6.3192362785339355
# epoch 23 Discrimator Loss 0.0 Generator Loss 9.306636810302734
# epoch 23 Discrimator Loss 0.03193725645542145 Generator Loss 10.522418975830078
# epoch 23 Discrimator Loss 0.03136357292532921 Generator Loss 14.26252269744873
# epoch 23 Discrimator Loss 0.0 Generator Loss 13.941293716430664
# epoch 23 Discrimator Loss 0.0 Generator Loss 4.567880153656006
# epoch 23 Discrimator Loss 0.0 Generator Loss 19.053722381591797
# epoch 23 Discrimator Loss 0.0 Generator Loss 13.760642051696777
# epoch 23 Discrimator Loss 0.03031887114048004 Generator Loss 9.650951385498047
# epoch 23 Discrimator Loss 0.0 Generator Loss 8.469158172607422
# epoch 23 Discrimator Loss 0.0 Generator Loss 6.2808098793029785
# epoch 23 Discrimator Loss 0.0044951848685741425 Generator Loss 5.302924156188965
# epoch 23 Discrimator Loss 0.0 Generator Loss 13.873292922973633
# epoch 23 Discrimator Loss 0.01233356911689043 Generator Loss 10.325445175170898
# epoch 24 Discrimator Loss 0.0 Generator Loss 7.604099273681641
# epoch 24 Discrimator Loss 0.16979610919952393 Generator Loss 12.747615814208984
# epoch 24 Discrimator Loss 0.0 Generator Loss 6.144984245300293
# epoch 24 Discrimator Loss 0.0 Generator Loss 12.465532302856445
# epoch 24 Discrimator Loss 0.04390290379524231 Generator Loss 16.15288543701172
# epoch 24 Discrimator Loss 0.0028293030336499214 Generator Loss 10.552825927734375
# epoch 24 Discrimator Loss 0.0 Generator Loss 6.591775417327881
# epoch 24 Discrimator Loss 0.030858561396598816 Generator Loss 17.219959259033203
# epoch 24 Discrimator Loss 0.0 Generator Loss 12.581371307373047
# epoch 24 Discrimator Loss 0.0 Generator Loss 17.856365203857422
# epoch 24 Discrimator Loss 0.0 Generator Loss 4.8354339599609375
# epoch 24 Discrimator Loss 0.015912465751171112 Generator Loss 19.395572662353516
# epoch 24 Discrimator Loss 0.0 Generator Loss 13.926069259643555
# epoch 24 Discrimator Loss 0.0 Generator Loss 9.190370559692383
# epoch 24 Discrimator Loss 0.05485234409570694 Generator Loss 6.229341983795166
# epoch 24 Discrimator Loss 0.0 Generator Loss 10.894503593444824
# epoch 24 Discrimator Loss 0.06465935707092285 Generator Loss 14.63968276977539
# epoch 24 Discrimator Loss 0.010728798806667328 Generator Loss 19.285078048706055
# epoch 24 Discrimator Loss 0.0 Generator Loss 4.205848693847656
# epoch 24 Discrimator Loss 0.0 Generator Loss 6.726301193237305
# epoch 24 Discrimator Loss 0.27713924646377563 Generator Loss 21.384475708007812
# epoch 24 Discrimator Loss 0.0 Generator Loss 8.878240585327148
# epoch 25 Discrimator Loss 0.0 Generator Loss 8.917259216308594
# epoch 25 Discrimator Loss 0.0 Generator Loss 19.41933822631836
# epoch 25 Discrimator Loss 0.0 Generator Loss 14.766416549682617
# epoch 25 Discrimator Loss 0.0 Generator Loss 16.50043487548828
# epoch 25 Discrimator Loss 0.016653750091791153 Generator Loss 13.92751693725586
# epoch 25 Discrimator Loss 0.0 Generator Loss 10.773484230041504
# epoch 25 Discrimator Loss 0.012712273746728897 Generator Loss 11.693000793457031
# epoch 25 Discrimator Loss 0.0 Generator Loss 6.655581951141357
# epoch 25 Discrimator Loss 0.0 Generator Loss 9.206615447998047
# epoch 25 Discrimator Loss 0.0 Generator Loss 6.600594520568848
# epoch 25 Discrimator Loss 0.0 Generator Loss 8.770435333251953
# epoch 25 Discrimator Loss 0.0 Generator Loss 10.674737930297852
# epoch 25 Discrimator Loss 0.0 Generator Loss 11.900567054748535
# epoch 25 Discrimator Loss 0.07139744609594345 Generator Loss 7.5270209312438965
# epoch 25 Discrimator Loss 0.0 Generator Loss 8.944587707519531
# epoch 25 Discrimator Loss 0.0 Generator Loss 11.540867805480957
# epoch 25 Discrimator Loss 0.003719254396855831 Generator Loss 10.885795593261719
# epoch 25 Discrimator Loss 0.126161590218544 Generator Loss 11.838920593261719
# epoch 25 Discrimator Loss 0.029291722923517227 Generator Loss 5.410848617553711
# epoch 25 Discrimator Loss 0.027934014797210693 Generator Loss 16.88409423828125
# epoch 25 Discrimator Loss 0.030411377549171448 Generator Loss 4.472832202911377
# epoch 25 Discrimator Loss 0.0 Generator Loss 8.335514068603516
# epoch 26 Discrimator Loss 0.0 Generator Loss 4.616885185241699
# epoch 26 Discrimator Loss 0.023213833570480347 Generator Loss 8.195898056030273
# epoch 26 Discrimator Loss 1.0332765579223633 Generator Loss 11.516790390014648
# epoch 26 Discrimator Loss 0.001697145402431488 Generator Loss 9.35403060913086
# epoch 26 Discrimator Loss 0.0452970489859581 Generator Loss 10.328746795654297
# epoch 26 Discrimator Loss 0.0 Generator Loss 8.346270561218262
# epoch 26 Discrimator Loss 0.17626285552978516 Generator Loss 4.7177534103393555
# epoch 26 Discrimator Loss 0.01184825785458088 Generator Loss 8.765588760375977
# epoch 26 Discrimator Loss 0.0 Generator Loss 8.336289405822754
# epoch 26 Discrimator Loss 0.0 Generator Loss 16.919055938720703
# epoch 26 Discrimator Loss 0.02542170137166977 Generator Loss 5.217411994934082
# epoch 26 Discrimator Loss 0.0 Generator Loss 9.8145751953125
# epoch 26 Discrimator Loss 0.0 Generator Loss 8.140090942382812
# epoch 26 Discrimator Loss 0.0 Generator Loss 13.455459594726562
# epoch 26 Discrimator Loss 0.004209275357425213 Generator Loss 9.304280281066895
# epoch 26 Discrimator Loss 0.0 Generator Loss 8.236411094665527
# epoch 26 Discrimator Loss 0.0 Generator Loss 9.756391525268555
# epoch 26 Discrimator Loss 0.0 Generator Loss 7.349818229675293
# epoch 26 Discrimator Loss 0.5421102046966553 Generator Loss 9.440611839294434
# epoch 26 Discrimator Loss 0.0 Generator Loss 11.718868255615234
# epoch 26 Discrimator Loss 0.016029808670282364 Generator Loss 6.260033130645752
# epoch 26 Discrimator Loss 0.0 Generator Loss 9.65097427368164
# epoch 27 Discrimator Loss 0.0 Generator Loss 9.09923267364502
# epoch 27 Discrimator Loss 0.0 Generator Loss 7.259873390197754
# epoch 27 Discrimator Loss 0.08191217482089996 Generator Loss 12.816083908081055
# epoch 27 Discrimator Loss 0.0167133379727602 Generator Loss 9.249580383300781
# epoch 27 Discrimator Loss 0.0 Generator Loss 11.79702377319336
# epoch 27 Discrimator Loss 0.0013313228264451027 Generator Loss 9.803653717041016
# epoch 27 Discrimator Loss 0.004871407523751259 Generator Loss 15.872008323669434
# epoch 27 Discrimator Loss 0.09097755700349808 Generator Loss 14.539043426513672
# epoch 27 Discrimator Loss 0.009330912493169308 Generator Loss 14.456985473632812
# epoch 27 Discrimator Loss 0.0 Generator Loss 8.404411315917969
# epoch 27 Discrimator Loss 0.0 Generator Loss 10.021309852600098
# epoch 27 Discrimator Loss 0.009681584313511848 Generator Loss 7.638736724853516
# epoch 27 Discrimator Loss 0.0 Generator Loss 7.660518646240234
# epoch 27 Discrimator Loss 0.0 Generator Loss 11.483510971069336
# epoch 27 Discrimator Loss 0.0 Generator Loss 12.207808494567871
# epoch 27 Discrimator Loss 0.0 Generator Loss 16.65052032470703
# epoch 27 Discrimator Loss 0.0 Generator Loss 14.190256118774414
# epoch 27 Discrimator Loss 0.0014598770067095757 Generator Loss 27.530193328857422
# epoch 27 Discrimator Loss 0.0 Generator Loss 6.297640800476074
# epoch 27 Discrimator Loss 0.09157447516918182 Generator Loss 18.52396011352539
# epoch 27 Discrimator Loss 0.01612812839448452 Generator Loss 7.67034912109375
# epoch 27 Discrimator Loss 0.0 Generator Loss 9.469667434692383
# epoch 28 Discrimator Loss 1.807939052581787 Generator Loss 15.035561561584473
# epoch 28 Discrimator Loss 0.0 Generator Loss 10.493515968322754
# epoch 28 Discrimator Loss 0.0 Generator Loss 6.685660362243652
# epoch 28 Discrimator Loss 0.0515659898519516 Generator Loss 7.64900541305542
# epoch 28 Discrimator Loss 4.270294189453125 Generator Loss 27.247793197631836
# epoch 28 Discrimator Loss 0.0202620942145586 Generator Loss 10.962679862976074
# epoch 30 Discrimator Loss 0.024218780919909477 Generator Loss 15.571621894836426
# epoch 30 Discrimator Loss 0.03140109032392502 Generator Loss 11.26834774017334
# ...
# epoch 194 Discrimator Loss 0.049900542944669724 Generator Loss 5.970592021942139
# epoch 194 Discrimator Loss 0.12032338976860046 Generator Loss 5.513840198516846
# epoch 194 Discrimator Loss 0.0 Generator Loss 10.77208423614502
# epoch 194 Discrimator Loss 0.054096948355436325 Generator Loss 16.15546417236328
# epoch 194 Discrimator Loss 0.0 Generator Loss 7.519966125488281
# epoch 194 Discrimator Loss 0.10408219695091248 Generator Loss 13.099637985229492
# epoch 194 Discrimator Loss 0.0 Generator Loss 9.952613830566406
# epoch 194 Discrimator Loss 0.0 Generator Loss 12.518531799316406
# epoch 194 Discrimator Loss 0.41096413135528564 Generator Loss 9.618461608886719
# epoch 194 Discrimator Loss 0.031015291810035706 Generator Loss 7.853891849517822
# epoch 194 Discrimator Loss 0.014046987518668175 Generator Loss 8.908989906311035
# epoch 194 Discrimator Loss 0.10968906432390213 Generator Loss 14.910186767578125
# epoch 194 Discrimator Loss 1.7318922281265259 Generator Loss 17.19707679748535
# epoch 194 Discrimator Loss 0.16403834521770477 Generator Loss 20.263530731201172
# epoch 194 Discrimator Loss 0.3433765769004822 Generator Loss 11.638962745666504
# epoch 194 Discrimator Loss 0.10741714388132095 Generator Loss 13.77311897277832
# epoch 194 Discrimator Loss 0.08473478257656097 Generator Loss 12.643939018249512
# epoch 195 Discrimator Loss 0.5771909952163696 Generator Loss 12.757652282714844
# epoch 195 Discrimator Loss 0.0 Generator Loss 11.740869522094727
# epoch 195 Discrimator Loss 0.0 Generator Loss 9.149662017822266
# epoch 195 Discrimator Loss 0.0 Generator Loss 11.453811645507812
# epoch 195 Discrimator Loss 0.038379352539777756 Generator Loss 10.186542510986328
# epoch 195 Discrimator Loss 0.0 Generator Loss 13.08190631866455
# epoch 195 Discrimator Loss 3.384866237640381 Generator Loss 2.939570665359497
# epoch 195 Discrimator Loss 0.07392827421426773 Generator Loss 12.108772277832031
# epoch 195 Discrimator Loss 0.07412087172269821 Generator Loss 9.636335372924805
# epoch 195 Discrimator Loss 0.0029387278482317924 Generator Loss 11.087955474853516
# epoch 195 Discrimator Loss 0.0 Generator Loss 10.002450942993164
# epoch 195 Discrimator Loss 0.4314800798892975 Generator Loss 24.378360748291016
# epoch 195 Discrimator Loss 0.06251534819602966 Generator Loss 9.081707000732422
# epoch 195 Discrimator Loss 0.0 Generator Loss 10.033239364624023
# epoch 195 Discrimator Loss 0.13089095056056976 Generator Loss 6.418521881103516
# epoch 195 Discrimator Loss 0.0 Generator Loss 12.909602165222168
# epoch 195 Discrimator Loss 0.0 Generator Loss 12.657867431640625
# epoch 195 Discrimator Loss 0.0 Generator Loss 11.433616638183594
# epoch 195 Discrimator Loss 0.010954318568110466 Generator Loss 14.359902381896973
# epoch 195 Discrimator Loss 0.0 Generator Loss 9.33613109588623
# epoch 195 Discrimator Loss 0.03298875689506531 Generator Loss 8.98996353149414
# epoch 197 Discrimator Loss 0.02440139651298523 Generator Loss 13.740418434143066
# epoch 197 Discrimator Loss 0.012200677767395973 Generator Loss 12.870315551757812
# epoch 197 Discrimator Loss 0.003279896453022957 Generator Loss 11.89767837524414
# epoch 197 Discrimator Loss 0.0451555997133255 Generator Loss 16.061323165893555
# epoch 197 Discrimator Loss 0.1390821933746338 Generator Loss 10.129314422607422
# epoch 197 Discrimator Loss 0.12741772830486298 Generator Loss 13.935077667236328
# epoch 198 Discrimator Loss 1.0740232467651367 Generator Loss 22.12476348876953
# epoch 198 Discrimator Loss 0.3426588475704193 Generator Loss 13.23560905456543
# epoch 198 Discrimator Loss 0.0 Generator Loss 15.891546249389648
# epoch 198 Discrimator Loss 0.13311472535133362 Generator Loss 8.12175178527832
# epoch 198 Discrimator Loss 0.09708000719547272 Generator Loss 14.65168571472168
# epoch 198 Discrimator Loss 0.0 Generator Loss 9.76998233795166
# epoch 198 Discrimator Loss 0.06755679100751877 Generator Loss 12.60382080078125
# epoch 198 Discrimator Loss 0.08378501236438751 Generator Loss 4.361891746520996
# epoch 198 Discrimator Loss 0.1624511480331421 Generator Loss 16.138635635375977
# epoch 198 Discrimator Loss 0.1285364031791687 Generator Loss 27.45269775390625
# epoch 198 Discrimator Loss 0.05001235753297806 Generator Loss 9.58018970489502
# epoch 198 Discrimator Loss 0.012828323990106583 Generator Loss 11.749151229858398
# epoch 198 Discrimator Loss 0.1024884283542633 Generator Loss 10.07540225982666
# epoch 198 Discrimator Loss 0.004902249202132225 Generator Loss 10.38178539276123
# epoch 198 Discrimator Loss 0.012526815757155418 Generator Loss 11.017461776733398
# epoch 198 Discrimator Loss 0.0 Generator Loss 8.644340515136719
# epoch 198 Discrimator Loss 0.0 Generator Loss 12.974609375
# epoch 198 Discrimator Loss 0.0 Generator Loss 6.9203691482543945
# epoch 198 Discrimator Loss 0.0 Generator Loss 9.871636390686035
# epoch 198 Discrimator Loss 0.01341979205608368 Generator Loss 9.530790328979492
# epoch 198 Discrimator Loss 0.0 Generator Loss 9.746797561645508
# epoch 198 Discrimator Loss 0.002233114093542099 Generator Loss 10.452991485595703
# epoch 199 Discrimator Loss 0.1680530309677124 Generator Loss 16.531898498535156
# epoch 199 Discrimator Loss 0.2810255289077759 Generator Loss 18.398462295532227
# epoch 199 Discrimator Loss 5.238076210021973 Generator Loss 1.7999027967453003
# epoch 199 Discrimator Loss 0.6514850854873657 Generator Loss 11.11269760131836
# epoch 199 Discrimator Loss 0.28659242391586304 Generator Loss 4.623400688171387
# epoch 199 Discrimator Loss 0.02097778022289276 Generator Loss 7.725625038146973
# epoch 199 Discrimator Loss 2.681875228881836 Generator Loss 2.7557497024536133
# epoch 199 Discrimator Loss 0.0016219094395637512 Generator Loss 11.430269241333008
# epoch 199 Discrimator Loss 0.4849575161933899 Generator Loss 0.11026868969202042
# epoch 199 Discrimator Loss 0.12890367209911346 Generator Loss 8.20686149597168
# epoch 199 Discrimator Loss 0.0 Generator Loss 8.990715026855469
# epoch 199 Discrimator Loss 0.07577794790267944 Generator Loss 18.491436004638672
# epoch 199 Discrimator Loss 0.02288716845214367 Generator Loss 8.968807220458984
# epoch 199 Discrimator Loss 0.0 Generator Loss 11.35468864440918
# epoch 199 Discrimator Loss 0.1390770971775055 Generator Loss 10.016538619995117
# epoch 199 Discrimator Loss 0.0 Generator Loss 8.078737258911133
# epoch 199 Discrimator Loss 0.16444161534309387 Generator Loss 15.285139083862305
# epoch 199 Discrimator Loss 0.0 Generator Loss 9.7953519821167
# epoch 199 Discrimator Loss 0.0 Generator Loss 5.640905380249023
# epoch 199 Discrimator Loss 0.43463200330734253 Generator Loss 9.80710506439209
# epoch 199 Discrimator Loss 0.4557223320007324 Generator Loss 7.531393051147461
# epoch 199 Discrimator Loss 0.03168953210115433 Generator Loss 8.077986717224121
# epoch 200 Discrimator Loss 0.0 Generator Loss 9.945459365844727
# epoch 200 Discrimator Loss 0.06595408171415329 Generator Loss 9.850326538085938
# epoch 200 Discrimator Loss 0.01442328467965126 Generator Loss 16.073978424072266
# epoch 200 Discrimator Loss 0.002812061458826065 Generator Loss 18.173601150512695
# epoch 200 Discrimator Loss 1.34031343460083 Generator Loss 9.23287296295166
# epoch 200 Discrimator Loss 0.13345037400722504 Generator Loss 8.226720809936523
# epoch 200 Discrimator Loss 0.3210648000240326 Generator Loss 11.687870025634766
# epoch 200 Discrimator Loss 1.282050371170044 Generator Loss 22.354541778564453
# epoch 200 Discrimator Loss 0.05272958427667618 Generator Loss 17.51384162902832
# epoch 200 Discrimator Loss 0.010859331116080284 Generator Loss 8.09587287902832
# epoch 200 Discrimator Loss 0.024169057607650757 Generator Loss 10.416082382202148
# epoch 200 Discrimator Loss 0.04218647629022598 Generator Loss 4.614162445068359
# epoch 200 Discrimator Loss 0.04725080728530884 Generator Loss 6.733249664306641
# epoch 200 Discrimator Loss 3.5538792610168457 Generator Loss 11.769451141357422
# epoch 200 Discrimator Loss 0.09148650616407394 Generator Loss 7.497780799865723
# epoch 200 Discrimator Loss 0.0 Generator Loss 9.621464729309082
# epoch 200 Discrimator Loss 2.20796537399292 Generator Loss 21.642240524291992
# epoch 200 Discrimator Loss 0.5949127674102783 Generator Loss 9.403867721557617
# epoch 200 Discrimator Loss 0.09401769936084747 Generator Loss 12.62025260925293
# epoch 200 Discrimator Loss 0.014299644157290459 Generator Loss 8.527151107788086
# epoch 200 Discrimator Loss 0.0 Generator Loss 6.727404594421387
# epoch 200 Discrimator Loss 0.04710007086396217 Generator Loss 10.589221954345703
# epoch 201 Discrimator Loss 0.09581203013658524 Generator Loss 10.0408935546875
# epoch 201 Discrimator Loss 0.2925305962562561 Generator Loss 17.777381896972656
# epoch 201 Discrimator Loss 0.0 Generator Loss 10.415294647216797
# epoch 201 Discrimator Loss 0.034978415817022324 Generator Loss 14.598573684692383
# epoch 201 Discrimator Loss 0.0 Generator Loss 14.476275444030762
# epoch 201 Discrimator Loss 0.0 Generator Loss 7.39682674407959
# epoch 201 Discrimator Loss 0.6212433576583862 Generator Loss 11.143373489379883
# epoch 201 Discrimator Loss 0.009483058005571365 Generator Loss 5.804417610168457
# epoch 201 Discrimator Loss 0.22692307829856873 Generator Loss 9.92246150970459
# epoch 201 Discrimator Loss 0.17031556367874146 Generator Loss 4.414925575256348
# epoch 201 Discrimator Loss 0.0848083570599556 Generator Loss 6.849925518035889
# epoch 201 Discrimator Loss 0.10513965785503387 Generator Loss 9.477533340454102
# epoch 201 Discrimator Loss 0.12484663724899292 Generator Loss 9.0069580078125
# epoch 201 Discrimator Loss 0.00872761569917202 Generator Loss 8.365726470947266
# epoch 201 Discrimator Loss 0.015253119170665741 Generator Loss 13.488042831420898
# epoch 201 Discrimator Loss 0.03452911227941513 Generator Loss 7.610686302185059
# epoch 201 Discrimator Loss 0.0 Generator Loss 11.340394973754883
# epoch 201 Discrimator Loss 0.06806960701942444 Generator Loss 13.732924461364746
# epoch 201 Discrimator Loss 0.01224152185022831 Generator Loss 6.648178577423096
# epoch 201 Discrimator Loss 0.038837019354104996 Generator Loss 11.504798889160156
# epoch 201 Discrimator Loss 0.01939503103494644 Generator Loss 8.362354278564453
# epoch 201 Discrimator Loss 0.0 Generator Loss 11.212362289428711
# epoch 202 Discrimator Loss 0.01829683780670166 Generator Loss 9.048925399780273
# epoch 202 Discrimator Loss 0.21815179288387299 Generator Loss 22.552570343017578
# epoch 202 Discrimator Loss 0.41135239601135254 Generator Loss 22.201704025268555
# epoch 202 Discrimator Loss 0.0 Generator Loss 11.615579605102539
# epoch 202 Discrimator Loss 0.0 Generator Loss 12.856382369995117
# epoch 202 Discrimator Loss 0.13259467482566833 Generator Loss 6.494631767272949
# epoch 202 Discrimator Loss 0.040072113275527954 Generator Loss 11.855327606201172
# epoch 202 Discrimator Loss 1.9700374603271484 Generator Loss 4.304388999938965
# epoch 202 Discrimator Loss 0.018324226140975952 Generator Loss 8.206257820129395
# epoch 202 Discrimator Loss 0.06602184474468231 Generator Loss 11.142754554748535
# epoch 202 Discrimator Loss 0.1520451307296753 Generator Loss 10.515802383422852
# epoch 202 Discrimator Loss 0.2823152244091034 Generator Loss 19.354736328125
# epoch 202 Discrimator Loss 0.108035147190094 Generator Loss 11.923822402954102
# epoch 202 Discrimator Loss 0.4136310815811157 Generator Loss 20.39655113220215
# epoch 202 Discrimator Loss 0.017646662890911102 Generator Loss 12.649456024169922
# epoch 202 Discrimator Loss 0.8770742416381836 Generator Loss 31.640850067138672
# epoch 202 Discrimator Loss 0.07731970399618149 Generator Loss 7.42710542678833
# epoch 202 Discrimator Loss 0.07882239669561386 Generator Loss 7.8677592277526855
# epoch 202 Discrimator Loss 0.0 Generator Loss 10.570647239685059
# epoch 202 Discrimator Loss 0.0778263658285141 Generator Loss 10.025007247924805
# epoch 202 Discrimator Loss 0.06743495166301727 Generator Loss 7.028264999389648
# epoch 202 Discrimator Loss 0.014261593110859394 Generator Loss 8.622118949890137
# epoch 203 Discrimator Loss 1.4585659503936768 Generator Loss -2.5379743576049805
# epoch 203 Discrimator Loss 0.0 Generator Loss 9.410323143005371
# epoch 203 Discrimator Loss 0.17764079570770264 Generator Loss 12.504631042480469
# epoch 203 Discrimator Loss 0.07025957852602005 Generator Loss 11.287633895874023
# epoch 203 Discrimator Loss 0.11004437506198883 Generator Loss 7.497900485992432
# epoch 203 Discrimator Loss 0.0 Generator Loss 9.317794799804688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-e9eded5033d2> in <module>()
# ----> 1 train(netDiscriminator, netGenerator, 0, epochs, optimizerD, optimizerG,loss_Discriminator, loss_Generator)
#
# <ipython-input-27-3a87c1b318bc> in train(netDiscriminator, netGenerator, epoch, epochs, optimizerD, optimizerG, loss_Discriminator, loss_Generator)
#      32       if(i%50 == 0):
#      33         print('epoch', epoch,'Discrimator Loss', total_loss.item(), 'Generator Loss', loss_Generator_fake.item())
# ---> 34       loss_Discriminator.append(total_loss.item())
#      35       loss_Generator.append(loss_Generator_fake.item())
#      36       #Saving Model after every 100th epoch
#
# KeyboardInterrupt:

# %%
Discriminator_checkpoint = torch.load(Discriminator_path)
Generator_checkpoint = torch.load(Generator_path)

# %%
Generator_checkpoint.keys()
# Out:
# dict_keys(['epoch', 'generator_model_state_dict', 'optimizer_generator_state_dict', 'loss'])

# %%
netDiscriminator.load_state_dict(Discriminator_checkpoint['discriminator_model_state_dict'])
optimizerD.load_state_dict(Discriminator_checkpoint['optimizer_discriminator_state_dict'])
netGenerator.load_state_dict(Generator_checkpoint['generator_model_state_dict'])
optimizerG.load_state_dict(Generator_checkpoint['optimizer_generator_state_dict'])
loss_Discriminator = Discriminator_checkpoint['loss']
loss_Generator = Generator_checkpoint['loss']

# %%
epoch = Discriminator_checkpoint['epoch']

# %%
epoch
# Out:
# 600

# %%
train(netDiscriminator,netGenerator, epoch, epochs, optimizerD, optimizerG, loss_Discriminator, loss_Generator )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-91790d2d5af7> in <module>()
# ----> 1 train(netDiscriminator,netGenerator, epoch, epochs, optimizerD, optimizerG, loss_Discriminator, loss_Generator )
#
# <ipython-input-18-dc41519c8c13> in train(netDiscriminator, netGenerator, epoch, epochs, optimizerD, optimizerG, loss_Discriminator, loss_Generator)
#       3   PATH_TO_FAKE = '/content/gdrive/My Drive/Fake Images/'
#       4   for epoch in range(epoch, epochs):
# ----> 5     for i, data in enumerate(dataloader,0):
#       6       #Train Discriminator
#       7       batch_data = data[0].to(device)
#
# NameError: name 'dataloader' is not defined

# %%
epoch_set = np.linspace(1,500, num = 500, dtype = 'int')

# %%
69312 / 64
# Out:
# 1083.0

# %%
loss_G = []
for i in range(0,len(loss_Generator),1083):
  loss_G.append(np.mean(loss_Generator[i:i+1083]))

# %%
loss_G = loss_G[0:500]

# %%
loss_D = []
for i in range(0,len(loss_Discriminator),1083):
  loss_D.append(np.mean(loss_Discriminator[i:i+1083]))

# %%
loss_D = loss_D[0:500]

# %%
plt.figure(figsize=(10,10))
plt.plot(epoch_set, loss_G, label = 'Generator Loss')
plt.plot(epoch_set, loss_D, label = 'Discriminator Loss')
plt.title('Generator and Discriminator loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
