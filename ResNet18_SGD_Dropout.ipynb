# %%
import tensorflow as tf

# %%
import keras

# %%
from keras.datasets import cifar100

# %%
from keras.utils import to_categorical

# %%
(train_X, train_Y_),(test_X, test_Y_) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step

# %%
train_Y = to_categorical(train_Y_)
test_Y = to_categorical(test_Y_)

# %%
train_X = train_X.astype('float32')/255
test_X = test_X.astype('float32')/255

# %%
from keras.models import Model

# %%
from keras.layers import  Conv2D, Dense, BatchNormalization, Flatten, MaxPool2D, Input, Dropout, AveragePooling2D,Add

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
def create_ResNet18_Network():
  input_layer = Input(shape = (32,32,3))
  conv_layer1 = Conv2D(filters = 32, kernel_size = (7,7) , strides = (2,2), padding = 'same', activation = 'relu')(input_layer)
  pool_layer1 = MaxPool2D(pool_size=(2,2), strides = (2,2))(conv_layer1)
  conv_layer2a = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(pool_layer1)
  conv_layer2b = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(conv_layer2a)
  add_layer1 = Add()([conv_layer2a, conv_layer2b])
  conv_layer2c = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(add_layer1)
  conv_layer2d = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(conv_layer2c)
  add_layer2 = Add()([conv_layer2c, conv_layer2d])
  conv_layer3a = Conv2D(filters = 64, kernel_size=(3,3), padding = 'same', activation = 'relu')(add_layer2)
  conv_layer3b = Conv2D(filters = 64, kernel_size=(3,3), padding = 'same', activation = 'relu')(conv_layer2c)
  add_layer3 =  Add()([conv_layer3a, conv_layer3b])
  conv_layer3c = Conv2D(filters = 64, kernel_size=(3,3), padding = 'same', activation = 'relu')(add_layer3)
  conv_layer3d = Conv2D(filters = 64, kernel_size=(3,3), padding = 'same', activation = 'relu')(conv_layer3c)
  dropout_layer1 = Dropout(rate = 0.2)(conv_layer3d)
  add_layer4 = Add()([conv_layer3c, dropout_layer1])
  #conv_layer4a = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(add_layer4)
  #conv_layer4b = Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu')(conv_layer4a)
  #add_layer5 = Add()([conv_layer4a, conv_layer4b])
  #conv_layer4c = Conv2D(filters = 32, kernel_size = (3,3), padding = 'same', activation = 'relu')(add_layer5)
  #conv_layer4d = Conv2D(filters = 32, kernel_size=(3,3), padding = 'same', activation = 'relu')(conv_layer4c)
  #add_layer6 = Add()([conv_layer4c, conv_layer4d])
  pool_layer4 = AveragePooling2D(pool_size = (2,2),strides=(1,1))(add_layer4)
  flatten = Flatten()(pool_layer4)
  dense1 = Dense(units = 256, activation = 'relu')(flatten)
  dropout = Dropout(rate = 0.2)(dense1)
  dense2 = Dense(100, activation = 'softmax')(dropout)
  model = Model(inputs = input_layer, outputs = dense2)
  return model

# %%
model  = create_ResNet18_Network()

# %%
model.compile(optimizer='sgd', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 32)   4736        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 32)     9248        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 32)     9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 32)     0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 32)     9248        add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 32)     9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 32)     0           conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     18496       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 8, 64)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 64)     0           conv2d_7[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 7, 7, 64)     0           add_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          803072      flatten[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          25700       dropout_1[0][0]
# ==================================================================================================
# Total params: 981,348
# Trainable params: 981,348
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
path = F'/content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5'

# %%
earlyStopping = EarlyStopping(monitor = 'val_accuracy', patience = 50)
checkpoint = ModelCheckpoint(filepath = path, monitor = 'val_accuracy',verbose = 2,  save_best_only=True, save_weights_only=True, mode = 'max')

# %%
history = model.fit(x = train_X, y = train_Y, batch_size = 32, epochs = 200, validation_split=0.1, callbacks=[checkpoint, earlyStopping])
# Out:
# Epoch 1/200
# 1407/1407 [==============================] - ETA: 0s - loss: 4.4999 - accuracy: 0.0213
# Epoch 00001: val_accuracy improved from -inf to 0.03400, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 9s 6ms/step - loss: 4.4999 - accuracy: 0.0213 - val_loss: 4.3595 - val_accuracy: 0.0340
# Epoch 2/200
# 1398/1407 [============================>.] - ETA: 0s - loss: 4.1755 - accuracy: 0.0570
# Epoch 00002: val_accuracy improved from 0.03400 to 0.08640, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 4.1746 - accuracy: 0.0572 - val_loss: 4.0022 - val_accuracy: 0.0864
# Epoch 3/200
# 1406/1407 [============================>.] - ETA: 0s - loss: 3.9011 - accuracy: 0.1010
# Epoch 00003: val_accuracy improved from 0.08640 to 0.13100, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.9011 - accuracy: 0.1010 - val_loss: 3.7594 - val_accuracy: 0.1310
# Epoch 4/200
# 1403/1407 [============================>.] - ETA: 0s - loss: 3.6993 - accuracy: 0.1369
# Epoch 00004: val_accuracy improved from 0.13100 to 0.14620, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.6994 - accuracy: 0.1368 - val_loss: 3.6800 - val_accuracy: 0.1462
# Epoch 5/200
# 1400/1407 [============================>.] - ETA: 0s - loss: 3.5347 - accuracy: 0.1658
# Epoch 00005: val_accuracy did not improve from 0.14620
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.5341 - accuracy: 0.1660 - val_loss: 3.7583 - val_accuracy: 0.1400
# Epoch 6/200
# 1407/1407 [==============================] - ETA: 0s - loss: 3.3928 - accuracy: 0.1897
# Epoch 00006: val_accuracy improved from 0.14620 to 0.18800, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.3928 - accuracy: 0.1897 - val_loss: 3.4443 - val_accuracy: 0.1880
# Epoch 7/200
# 1401/1407 [============================>.] - ETA: 0s - loss: 3.2622 - accuracy: 0.2138
# Epoch 00007: val_accuracy improved from 0.18800 to 0.20680, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.2618 - accuracy: 0.2138 - val_loss: 3.2656 - val_accuracy: 0.2068
# Epoch 8/200
# 1407/1407 [==============================] - ETA: 0s - loss: 3.1471 - accuracy: 0.2350
# Epoch 00008: val_accuracy improved from 0.20680 to 0.22640, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.1471 - accuracy: 0.2350 - val_loss: 3.2758 - val_accuracy: 0.2264
# Epoch 9/200
# 1402/1407 [============================>.] - ETA: 0s - loss: 3.0403 - accuracy: 0.2567
# Epoch 00009: val_accuracy did not improve from 0.22640
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.0397 - accuracy: 0.2568 - val_loss: 3.3074 - val_accuracy: 0.2036
# Epoch 10/200
# 1407/1407 [==============================] - ETA: 0s - loss: 2.9470 - accuracy: 0.2745
# Epoch 00010: val_accuracy improved from 0.22640 to 0.25480, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.9470 - accuracy: 0.2745 - val_loss: 3.0216 - val_accuracy: 0.2548
# Epoch 11/200
# 1399/1407 [============================>.] - ETA: 0s - loss: 2.8549 - accuracy: 0.2945
# Epoch 00011: val_accuracy did not improve from 0.25480
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.8547 - accuracy: 0.2943 - val_loss: 3.1382 - val_accuracy: 0.2448
# Epoch 12/200
# 1405/1407 [============================>.] - ETA: 0s - loss: 2.7657 - accuracy: 0.3078
# Epoch 00012: val_accuracy improved from 0.25480 to 0.26940, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.7656 - accuracy: 0.3078 - val_loss: 2.9725 - val_accuracy: 0.2694
# Epoch 13/200
# 1405/1407 [============================>.] - ETA: 0s - loss: 2.6859 - accuracy: 0.3236
# Epoch 00013: val_accuracy improved from 0.26940 to 0.29820, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.6857 - accuracy: 0.3237 - val_loss: 2.8403 - val_accuracy: 0.2982
# Epoch 14/200
# 1400/1407 [============================>.] - ETA: 0s - loss: 2.6038 - accuracy: 0.3381
# Epoch 00014: val_accuracy improved from 0.29820 to 0.29900, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.6033 - accuracy: 0.3381 - val_loss: 2.8436 - val_accuracy: 0.2990
# Epoch 15/200
# 1401/1407 [============================>.] - ETA: 0s - loss: 2.5275 - accuracy: 0.3554
# Epoch 00015: val_accuracy improved from 0.29900 to 0.30700, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.5274 - accuracy: 0.3554 - val_loss: 2.8188 - val_accuracy: 0.3070
# Epoch 16/200
# 1402/1407 [============================>.] - ETA: 0s - loss: 2.4527 - accuracy: 0.3728
# Epoch 00016: val_accuracy did not improve from 0.30700
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.4527 - accuracy: 0.3728 - val_loss: 2.8948 - val_accuracy: 0.2936
# Epoch 17/200
# 1407/1407 [==============================] - ETA: 0s - loss: 2.3808 - accuracy: 0.3883
# Epoch 00017: val_accuracy improved from 0.30700 to 0.31060, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.3808 - accuracy: 0.3883 - val_loss: 2.8547 - val_accuracy: 0.3106
# Epoch 18/200
# 1398/1407 [============================>.] - ETA: 0s - loss: 2.3036 - accuracy: 0.4045
# Epoch 00018: val_accuracy improved from 0.31060 to 0.31120, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.3039 - accuracy: 0.4047 - val_loss: 2.8307 - val_accuracy: 0.3112
# Epoch 19/200
# 1399/1407 [============================>.] - ETA: 0s - loss: 2.2339 - accuracy: 0.4188
# Epoch 00019: val_accuracy did not improve from 0.31120
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.2346 - accuracy: 0.4187 - val_loss: 2.8339 - val_accuracy: 0.3078
# Epoch 20/200
# 1407/1407 [==============================] - ETA: 0s - loss: 2.1650 - accuracy: 0.4335
# Epoch 00020: val_accuracy improved from 0.31120 to 0.32040, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.1650 - accuracy: 0.4335 - val_loss: 2.8895 - val_accuracy: 0.3204
# Epoch 21/200
# 1398/1407 [============================>.] - ETA: 0s - loss: 2.0987 - accuracy: 0.4450
# Epoch 00021: val_accuracy improved from 0.32040 to 0.33580, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.0995 - accuracy: 0.4450 - val_loss: 2.7021 - val_accuracy: 0.3358
# Epoch 22/200
# 1405/1407 [============================>.] - ETA: 0s - loss: 2.0271 - accuracy: 0.4609
# Epoch 00022: val_accuracy improved from 0.33580 to 0.33620, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 2.0269 - accuracy: 0.4610 - val_loss: 2.8633 - val_accuracy: 0.3362
# Epoch 23/200
# 1407/1407 [==============================] - ETA: 0s - loss: 1.9528 - accuracy: 0.4763
# Epoch 00023: val_accuracy did not improve from 0.33620
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.9528 - accuracy: 0.4763 - val_loss: 2.9031 - val_accuracy: 0.3224
# Epoch 24/200
# 1404/1407 [============================>.] - ETA: 0s - loss: 1.8894 - accuracy: 0.4906
# Epoch 00024: val_accuracy improved from 0.33620 to 0.33980, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.8895 - accuracy: 0.4906 - val_loss: 2.7848 - val_accuracy: 0.3398
# Epoch 25/200
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.8155 - accuracy: 0.5080
# Epoch 00025: val_accuracy did not improve from 0.33980
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.8155 - accuracy: 0.5079 - val_loss: 2.9080 - val_accuracy: 0.3146
# Epoch 26/200
# 1407/1407 [==============================] - ETA: 0s - loss: 1.7507 - accuracy: 0.5222
# Epoch 00026: val_accuracy did not improve from 0.33980
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7507 - accuracy: 0.5222 - val_loss: 2.9240 - val_accuracy: 0.3214
# Epoch 27/200
# 1398/1407 [============================>.] - ETA: 0s - loss: 1.6879 - accuracy: 0.5356
# Epoch 00027: val_accuracy improved from 0.33980 to 0.34400, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6878 - accuracy: 0.5356 - val_loss: 2.8716 - val_accuracy: 0.3440
# Epoch 28/200
# 1399/1407 [============================>.] - ETA: 0s - loss: 1.6212 - accuracy: 0.5473
# Epoch 00028: val_accuracy improved from 0.34400 to 0.34480, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6217 - accuracy: 0.5470 - val_loss: 2.8321 - val_accuracy: 0.3448
# Epoch 29/200
# 1403/1407 [============================>.] - ETA: 0s - loss: 1.5529 - accuracy: 0.5673
# Epoch 00029: val_accuracy did not improve from 0.34480
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5531 - accuracy: 0.5673 - val_loss: 3.1920 - val_accuracy: 0.2940
# Epoch 30/200
# 1402/1407 [============================>.] - ETA: 0s - loss: 1.4856 - accuracy: 0.5821
# Epoch 00030: val_accuracy did not improve from 0.34480
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4850 - accuracy: 0.5823 - val_loss: 3.0106 - val_accuracy: 0.3358
# Epoch 31/200
# 1401/1407 [============================>.] - ETA: 0s - loss: 1.4294 - accuracy: 0.5924
# Epoch 00031: val_accuracy improved from 0.34480 to 0.34500, saving model to /content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1
val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.3247 - accuracy: 0.8960 - val_loss: 5.6659 - val_accuracy: 0.3280
# Epoch 75/200
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.3270 - accuracy: 0.8961
# Epoch 00075: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.3271 - accuracy: 0.8961 - val_loss: 5.8296 - val_accuracy: 0.3166
# Epoch 76/200
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.8981
# Epoch 00076: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.3176 - accuracy: 0.8980 - val_loss: 6.0729 - val_accuracy: 0.3204
# Epoch 77/200
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.3145 - accuracy: 0.8998
# Epoch 00077: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.3146 - accuracy: 0.8996 - val_loss: 5.4967 - val_accuracy: 0.3362
# Epoch 78/200
# 1407/1407 [==============================] - ETA: 0s - loss: 0.3004 - accuracy: 0.9038
# Epoch 00078: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.3004 - accuracy: 0.9038 - val_loss: 5.8773 - val_accuracy: 0.3098
# Epoch 79/200
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.9070
# Epoch 00079: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2965 - accuracy: 0.9070 - val_loss: 5.9452 - val_accuracy: 0.3302
# Epoch 80/200
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.9070
# Epoch 00080: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2923 - accuracy: 0.9069 - val_loss: 6.1174 - val_accuracy: 0.2868
# Epoch 81/200
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.2835 - accuracy: 0.9073
# Epoch 00081: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2835 - accuracy: 0.9073 - val_loss: 6.2334 - val_accuracy: 0.3272
# Epoch 82/200
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.2855 - accuracy: 0.9075
# Epoch 00082: val_accuracy did not improve from 0.35660
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2853 - accuracy: 0.9076 - val_loss: 6.5044 - val_accuracy: 0.3128

# %%
model.load_weights('/content/gdrive/My Drive/Weights/ResNet18_SGD_Dropout.h5')

# %%
y_pred  = model.predict(test_X)

# %%
y_pred = y_pred.argmax(-1)

# %%
y_true = test_Y.argmax(-1)

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score

# %%
def get_all_metrics(y_pred, y_true):
  precision = precision_score(y_true,y_pred, average = 'weighted')
  recall = recall_score(y_true , y_pred, average= 'weighted')
  accuracy = accuracy_score(y_true, y_pred)
  return precision, recall, accuracy

# %%
prec, recall, accuracy = get_all_metrics(y_pred, y_true)

# %%
print('Precision:', prec)
# Out:
# Precision: 0.3672759149291171

# %%
print('Recall', recall)
# Out:
# Recall 0.357

# %%
print('Accuracy', accuracy)
# Out:
# Accuracy 0.357

# %%
import matplotlib.pyplot as plt

# %%
history_dict = history.history
print(history_dict.keys())
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'r', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
